# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - startup valuation
# - investors
# - employee growth
# - sector
# - geography

# %%
df = pd.read_csv('data/raw/CompanySimilarRelation.csv')

# %%
len(df)
# Out:
# 3056760

# %%
df.tail()
# Out:
#          CompanyID SimilarCompanyID                 SimilarCompanyName  \
# 3056755  436141-18        110772-01                  Cognition Medical
# 3056756  436141-18        286210-09  Central Texas Retina And Vitreous
# 3056757  436141-18        299335-78                     Lymphesthetics
# 3056758  436141-18        542704-51                           CADET NM
# 3056759  436141-18         58616-29                            OrganOx
#
#          SimilarityRank  SimilarityScore IsCompetitor  \
# 3056755               6            91.36           No
# 3056756               7            91.22           No
# 3056757               8            91.17           No
# 3056758               9            91.09           No
# 3056759              10            91.05           No
#
#                                         SimilarDescription  \
# 3056755  Developer of a medical device intended to redu...
# 3056756  Provider of retina and vitreous medical servic...
# ...
